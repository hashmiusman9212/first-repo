# %% [markdown]
# <a href="https://colab.research.google.com/github/hashmiusman9212/first-repo/blob/main/class_22_(pandas%5BAPIs%5D).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import requests as rq

# %%
from bs4 import BeautifulSoup as bs

# %%
url = 'http://api.plos.org/search?q=title:%22Drosophila%22%20and%20body:%22RNA%22&fl=id&start=100&rows=100'

# %%
data = rq.get(url)
json_data = data.json()
print(json_data['response']['docs'])

# %%
dataframe = pd.DataFrame(json_data['response']['docs'])

# %%
dataframe
# Out:
#                               id
# 0   10.1371/journal.pbio.3000094
# 1   10.1371/journal.pgen.0020154
# 2   10.1371/journal.pone.0020511
# 3   10.1371/journal.pone.0000490
# 4   10.1371/journal.pone.0070067
# ..                           ...
# 95  10.1371/journal.pone.0071686
# 96  10.1371/journal.pbio.1001420
# 97  10.1371/journal.pbio.2000532
# 98  10.1371/journal.pgen.1006297
# 99  10.1371/journal.pgen.1003061
#
# [100 rows x 1 columns]

# %%
data
# Out:
# <Response [200]>

# %%
url = 'https://data.cityofchicago.org/resource/ydr8-5enu.json'

# %%
data = rq.get(url)
json_data = data.json()
print(json_data)
# Out:
# [{'id': '1830273', 'permit_': '100190752', 'permit_type': 'PERMIT - SIGNS', 'review_type': 'SIGN PERMIT', 'application_start_date': '2007-10-16T00:00:00.000', 'issue_date': '2008-03-05T00:00:00.000', 'processing_time': '141', 'street_number': '6349', 'street_direction': 'S', 'street_name': 'COTTAGE GROVE', 'suffix': 'AVE', 'work_description': 'INSTALL BUILDING SIGN', 'building_fee_paid': '70', 'zoning_fee_paid': '75', 'other_fee_paid': '0', 'subtotal_paid': '145', 'building_fee_unpaid': '0', 'zoning_fee_unpaid': '0', 'other_fee_unpaid': '0', 'subtotal_unpaid': '0', 'building_fee_waived': '0', 'zoning_fee_waived': '0', 'other_fee_waived': '0', 'subtotal_waived': '0', 'total_fee': '145', 'contact_1_type': 'SIGN CONTRACTOR', 'contact_1_name': 'JAS. D. AHERN CO.', 'contact_1_city': 'CHICAGO X', 'contact_1_state': 'IL', 'contact_1_zipcode': '60623', 'reported_cost': '2000', 'pin1': '20-23-100-005'}, {'id': '2060019', 'permit_': '100296510', 'permit_type': 'PERMIT - ELECTRIC WIRING', 'revi
# ...

# %%
dataframe = pd.DataFrame(json_data)

# %%
dataframe
# Out:
#           id    permit_  ... contact_12_zipcode pin8
# 0    1830273  100190752  ...                NaN  NaN
# 1    2060019  100296510  ...                NaN  NaN
# 2    1671981  100108067  ...                NaN  NaN
# 3    2832499  100696131  ...                NaN  NaN
# 4    3053734  100830913  ...                NaN  NaN
# ..       ...        ...  ...                ...  ...
# 995  2055280  100294218  ...                NaN  NaN
# 996  2067124  100300167  ...                NaN  NaN
# 997  1959093  100257083  ...                NaN  NaN
# 998  2000060  100270193  ...                NaN  NaN
# 999  1946947  100250110  ...                NaN  NaN
#
# [1000 rows x 108 columns]

# %%
dataframe.columns
# Out:
# Index(['id', 'permit_', 'permit_type', 'review_type', 'application_start_date',
#        'issue_date', 'processing_time', 'street_number', 'street_direction',
#        'street_name',
#        ...
#        'contact_11_name', 'contact_11_city', 'contact_11_state',
#        'contact_11_zipcode', 'contact_12_type', 'contact_12_name',
#        'contact_12_city', 'contact_12_state', 'contact_12_zipcode', 'pin8'],
#       dtype='object', length=108)

# %%
cleandata = dataframe.dropna(axis = 1)

# %%
cleandata[cleandata['permit_type'] == 'PERMIT - ELECTRIC WIRING']
# Out:
#           id    permit_  ... total_fee reported_cost
# 1    2060019  100296510  ...        50         70000
# 2    1671981  100108067  ...        40             0
# 3    2832499  100696131  ...       150         39600
# 4    3053734  100830913  ...       300         15000
# 6    3100507  100858773  ...       225         85000
# ..       ...        ...  ...       ...           ...
# 986  1955509  100255074  ...        50             1
# 990  1965658  100260670  ...        50          1500
# 995  2055280  100294218  ...        50             1
# 997  1959093  100257083  ...       175         10000
# 998  2000060  100270193  ...        50           252
#
# [445 rows x 23 columns]

# %%
cleandata
# Out:
#           id    permit_  ... total_fee reported_cost
# 0    1830273  100190752  ...       145          2000
# 1    2060019  100296510  ...        50         70000
# 2    1671981  100108067  ...        40             0
# 3    2832499  100696131  ...       150         39600
# 4    3053734  100830913  ...       300         15000
# ..       ...        ...  ...       ...           ...
# 995  2055280  100294218  ...        50             1
# 996  2067124  100300167  ...       175             1
# 997  1959093  100257083  ...       175         10000
# 998  2000060  100270193  ...        50           252
# 999  1946947  100250110  ...       327          1500
#
# [1000 rows x 23 columns]
